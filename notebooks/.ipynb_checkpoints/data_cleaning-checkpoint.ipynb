# %%
import numpy as np
import pandas as pd
import re

from pathlib import Path

# %%
training_path = Path().resolve().parents[0] / 'data' / 'WikiLarge_Train.csv'

# %%
df = pd.read_csv(training_path)

# %%
df.head()
# Out:
#                                        original_text  label
# 0  There is manuscript evidence that Austen conti...      1
# 1  In a remarkable comparative analysis , Mandaea...      1
# 2  Before Persephone was released to Hermes , who...      1
# 3  Cogeneration plants are commonly found in dist...      1
# 4  Geneva -LRB- , ; , ; , ; ; -RRB- is the second...      1

# %%
def remove_lrb_rrb_tags(dataframe: pd.DataFrame) -> pd.DataFrame:
    """Removes -LRB-...-RRB- tags along with all text between from 'original_text' column.
    
    Expected dataframe columns:
        original_text: str
    
    :return pd.DataFrame: the passed DataFrame cleaned
    """
    dataframe.original_text = dataframe.original_text.str.replace(r' -LRB-(.*?)-RRB-', '', regex=True)
    return dataframe

def test_remove_lrb_rrb_tags() -> None:
    df = pd.DataFrame({'original_text': ['Do not touch', 'Replace -LRB-xxx2123;;;;;!!!-RRB- me']})
    expected_df = pd.DataFrame({'original_text': ['Do not touch', 'Replace me']})
    assert remove_lrb_rrb_tags(df).original_text.equals(expected_df.original_text)
    
test_remove_lrb_rrb_tags()

# %%
def replace_html_char_codes_with_char(dataframe: pd.DataFrame) -> pd.DataFrame:
    """Replaces char codes (e.g. &ndash;) with their respective characters.
    
    Expected dataframe columns:
        original_text: str
    
    :return pd.DataFrame: the passed DataFrame cleaned
    """ # TODO: Find/compile CSV of all codes and dynamically import and replace all
    characters: Dict[str, str] = { # Code: Character
        '&ndash;': '–',
        '&mdash;': '—',
    }
    for code, character in characters.items():
        dataframe.original_text = dataframe.original_text.str.replace(f"{code[0]} {code[1:-1]} {code[-1]}", character)
    return dataframe

def test_replace_html_char_codes_with_char() -> None:
    df = pd.DataFrame({'original_text': ['Do not touch', 'Replace & ndash ; me', 'Replace & mdash ; me']})
    expected_df = pd.DataFrame({'original_text': ['Do not touch', 'Replace – me', 'Replace — me']})
    assert replace_char_codes_with_char(df).original_text.equals(expected_df.original_text)
    
test_replace_html_char_codes_with_char()

# %%
def clean_dataset(dataframe: pd.DataFrame) -> pd.DataFrame:
    """Performs all required data cleaning on all records in the passed DataFrame.
    
    Expected dataframe columns:
        original_text: str
        label: int (0 or 1)
    
    :return pd.DataFrame: the passed DataFrame cleaned
    """
    cleaning_steps = [
        remove_lrb_rrb_tags,
    ]
    for cleaning in cleaning_steps:
        dataframe = cleaning(dataframe)
    return dataframe

# %%
clean_dataset(df).head(50)
# Out:
#                                         original_text  label
# 0   There is manuscript evidence that Austen conti...      1
# 1   In a remarkable comparative analysis , Mandaea...      1
# 2   Before Persephone was released to Hermes , who...      1
# 3   Cogeneration plants are commonly found in dist...      1
# 4   Geneva is the second-most-populous city in Swi...      1
# 5   When Japan earned another race on the F1 sched...      1
# 6   This marked the first motorcycle racing event ...      1
# 7   Ka La Ku'oko ' a : The Kingdom of Hawai`i is o...      1
# 8   A scythe is an agricultural hand tool for mowi...      1
# 9   Toshihide Saito is a Japanese football defender .      1
# 10  Many still refer to 25 , 50 and 75 paise as 4 ...      1
# 11  In Holland they were called Stadspijpers , in ...      1
# 12  Plays and comic puppet theater loosely based o...      1
# 13  Directed by Jon Avnet and written by Fannie Fl...      1
# 14  Beaumont-Pied-de-B Å '' uf is a commune in the...      1
# 15  In September 1869 , O'Reilly escaped and was r...      1
# 16  The Algerian government cut the electricity su...      1
# 17  Castleton is a honeypot village in the Derbysh...      1
# 18  Sensing of both the external and internal envi...      1
# 19  The width of the slide rule is quoted in terms...      1
# 20  May 27 , 1199 Friday -- John Lackland became K...      1
# 21  A very wide covered footbridge joins all platf...      1
# 22  Its widespread presence in many seeds and frui...      1
# 23  Country Music Television , or CMT , is an Amer...      1
# 24  Free content , or free information , is any ki...      1
# 25  Sea surface temperature is the water temperatu...      1
# 26  They take up oxygen in the lungs or gills and ...      1
# 27  He has subsequently written a further nine pla...      1
# 28  Lemon meringue pie is a type of baked pie , us...      1
# 29  A veritable reference book to Thunderbolt 's m...      1
# 30  On July 29 , 2008 the Palace announced that Ki...      1
# 31                             F. W. D. Brie , 1906 .      1
# 32  Simon Boccanegra is an opera with a prologue a...      1
# 33  On June 6 , 2000 , ten days before the movie w...      1
# 34  The Bushehr Nuclear Power Plant is a nuclear p...      1
# 35  In 2002 , Ortiz hit .272 for Minnesota , with ...      1
# 36  As a result the paper 's coverage changed radi...      1
# 37  The King charges the Prince to go to Earth wit...      1
# 38  Marklohe is a municipality in the district of ...      1
# 39  Chronic obstructive pulmonary disease , inters...      1
# 40  Glenn Thomas Jacobs is an American professiona...      1
# 41  Sudan is situated in northern Africa , borderi...      1
# 42  Shades of red and orange may sometimes appear ...      1
# 43  Also known as Hentchak , Henchak , Social-Demo...      1
# 44  Guitars are traditionally constructed of vario...      1
# 45  The player takes on the role of an engineer na...      1
# 46  Sergio PÃ rez Mendoza , also known as '' Checo...      1
# 47  To order the book as a bound book , click the ...      1
# 48  The conflict between his parents about religio...      1
# 49  1810 & ndash ; Ernst Kummer , German mathemati...      1
